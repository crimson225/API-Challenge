# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import csv
import json
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 607

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
cities
# Out:
# ['touros',
#  'east london',
#  'bethel',
#  'port elizabeth',
#  'alugan',
#  'puerto ayora',
#  'punta arenas',
#  'nikolskoye',
#  'tuktoyaktuk',
#  'santa quiteria',
#  'butaritari',
#  'wamba',
#  'hilo',
#  'camacupa',
#  'norman wells',
#  'port lincoln',
#  'mataura',
#  'bandarbeyla',
#  'cape town',
#  'njombe',
#  'ushuaia',
#  'serenje',
#  'trapani',
#  'nouadhibou',
#  'katsuura',
#  'xining',
#  'hasaki',
#  'taolanaro',
#  'kapaa',
#  'shimoda',
#  'nioro',
#  'do gonbadan',
#  'saint-philippe',
#  'rikitea',
#  'ponta do sol',
#  'provideniya',
#  'hun',
#  'kaura namoda',
#  'san ramon',
#  'torbay',
#  'hermanus',
#  'road town',
#  'mount isa',
#  'bluff',
#  'mariental',
#  'portree',
#  'sao filipe',
#  'sitka',
#  'kutum',
#  'castro',
#  'vaini',
#  'albany',
#  'arraial do cabo',
#  'lompoc',
#  'palabuhanratu',
#  'ternate',
#  'laurel',
#  'caravelas',
#  'yaounde',
#  'pailon',
#  'chara',
#  'nhulunbuy',
#  'fort saint james',
#  'luderitz',
#  'shaartuz',
#  'sao joao da barra',
#  'vaitupu',
#  'hambantota',
#  'vostok',
#  'saskylakh',
#  'kattivakkam',
#  'aanekoski',
#  'superior',
#  'sembakung',
#  'pevek',
#  'acapulco',
#  'narang',
#  'yellowknife',
#  'atuona',
#  'hamilton',
#  'dikson',
#  'adrar',
#  'khipro',
#  'georgetown',
#  'busselton',
#  'tigil',
#  'jamestown',
#  'high rock',
#  'walvis bay',
#  'cidreira',
#  'vallenar',
#  'flin flon',
#  'hithadhoo',
#  'chokurdakh',
#  'puerto ayacucho',
#  'axim',
#  'ilulissat',
#  'thompson',
#  'faanui',
#  'cabo san lucas',
#  'aswan',
#  'burica',
#  'nome',
#  'saleaula',
#  'ancud',
#  'leningradskiy',
#  'chuy',
#  'klaksvik',
#  'pangnirtung',
#  'awjilah',
#  'bredasdorp',
#  'tuatapere',
#  'necochea',
#  'barrow',
#  'husavik',
#  'san isidro',
#  'pandan',
#  'soyo',
#  'bucerias',
#  'urdzhar',
#  'dolbeau',
#  'fare',
#  'kodiak',
#  'tumannyy',
#  'saint george',
#  'petropavlovsk-kamchatskiy',
#  'qaanaaq',
#  'emilio carranza',
#  'kavieng',
#  'ruteng',
#  'boende',
#  'douglas',
#  'khatanga',
#  'cayenne',
#  'vila velha',
#  'araguatins',
#  'maceio',
#  'tasiilaq',
#  'tsagan aman',
#  'roald',
#  'nuuk',
#  'coquimbo',
#  'pacifica',
#  'iberia',
#  'komsomolskoye',
#  'karratha',
#  'keffi',
#  'tautira',
#  'airai',
#  'longyearbyen',
#  'winslow',
#  'nabire',
#  'illoqqortoormiut',
#  'korhogo',
#  'rundu',
#  'ribeira grande',
#  'tula',
#  'henties bay',
#  'veraval',
#  'hobart',
#  'marsabit',
#  'shurugwi',
#  'shelburne',
#  'amderma',
#  'chapais',
#  'beloha',
#  'ningbo',
#  'bambous virieux',
#  'havelock',
#  'havoysund',
#  'haimen',
#  'olinda',
#  'santo domingo',
#  'shiyan',
#  'barentsburg',
#  'mount gambier',
#  'noumea',
#  'moose factory',
#  'palmer',
#  'clyde river',
#  'murdochville',
#  'shingu',
#  'ponta delgada',
#  'lavrentiya',
#  'manakara',
#  'severo-kurilsk',
#  'okhotsk',
#  'vaitape',
#  'umzimvubu',
#  'new norfolk',
#  'hailey',
#  'campbell river',
#  'mahebourg',
#  'san antero',
#  'maxixe',
#  'sentyabrskiy',
#  'nakuru',
#  'wanaka',
#  'mys shmidta',
#  'sorland',
#  'candawaga',
#  'uyuni',
#  'bayan',
#  'bilopillya',
#  'attawapiskat',
#  'iquique',
#  'tripoli',
#  'haines junction',
#  'gorontalo',
#  'naze',
#  'kapoeta',
#  'san juan',
#  'vryburg',
#  'port moresby',
#  'taltal',
#  'carnarvon',
#  'lagoa',
#  'rio gallegos',
#  'namibe',
#  'lebu',
#  'avram iancu',
#  'muzhi',
#  'chabahar',
#  'mecca',
#  'port alfred',
#  'juneau',
#  'jiuquan',
#  'saldanha',
#  'oksfjord',
#  'najran',
#  'la ronge',
#  'terrace bay',
#  'upernavik',
#  'cherskiy',
#  'jizan',
#  'jos',
#  'vestmannaeyjar',
#  'burnie',
#  'talnakh',
#  'mbala',
#  'hami',
#  'apodi',
#  'fortuna',
#  'portland',
#  'ostrovnoy',
#  'saucillo',
#  'langham',
#  'karpathos',
#  'baykit',
#  'fuyang',
#  'komsomolskiy',
#  'chester',
#  'leua',
#  'pangai',
#  'lorengau',
#  'vila franca do campo',
#  'karaul',
#  'las juntas',
#  'polson',
#  'cairns',
#  'roros',
#  'ksenyevka',
#  'qasigiannguit',
#  'aksha',
#  'port hardy',
#  'brae',
#  'belushya guba',
#  'mar del plata',
#  'vanimo',
#  'botwood',
#  'broken hill',
#  'sergeyevka',
#  'yanchukan',
#  'san cristobal',
#  'kedougou',
#  'richards bay',
#  'ust-ilimsk',
#  'clarence town',
#  'baneh',
#  'buin',
#  'constitucion',
#  'anloga',
#  'kuusamo',
#  'lengshuitan',
#  'lagos',
#  'tessalit',
#  'uige',
#  'lakhnadon',
#  'yumen',
#  'coihaique',
#  'chumikan',
#  'honiara',
#  'muhos',
#  'waipawa',
#  'shizunai',
#  'guerrero negro',
#  'manambrag',
#  'san patricio',
#  'kandrian',
#  'tura',
#  'kaitangata',
#  'lampa',
#  'leh',
#  'jackson',
#  'tiksi',
#  'ardakan',
#  'matara',
#  'jiexiu',
#  'diu',
#  'ginda',
#  'avarua',
#  'hailar',
#  'puerto el triunfo',
#  'isangel',
#  'ilanskiy',
#  'ust-ishim',
#  'victoria',
#  'alghero',
#  'panguna',
#  'souillac',
#  'rapid valley',
#  'mayo',
#  'suntar',
#  'ust-kut',
#  'winnemucca',
#  'malwan',
#  'kruisfontein',
#  'praia',
#  'pitimbu',
#  'gorkovskoye',
#  'aykhal',
#  'narsaq',
#  'nizhneyansk',
#  'sikonge',
#  'verkhnyaya toyma',
#  'bam',
#  'pemberton',
#  'esperance',
#  'lethem',
#  'olafsvik',
#  'townsville',
#  'artyk',
#  'praxedis guerrero',
#  'fukue',
#  'sao gabriel da cachoeira',
#  'bahia blanca',
#  'samusu',
#  'wattegama',
#  'viedma',
#  'raga',
#  'bathsheba',
#  'tsihombe',
#  'antalaha',
#  'leeuwarden',
#  'lata',
#  'sorvag',
#  'whitefish',
#  'kyren',
#  'rocha',
#  'lucea',
#  'muisne',
#  'san diego de la union',
#  'kholodnyy',
#  'littlehampton',
#  'pemba',
#  'baruun-urt',
#  'erdaojiang',
#  'santa cruz',
#  'lubao',
#  'salinopolis',
#  'arlit',
#  'nanortalik',
#  'ulladulla',
#  'gravdal',
#  'aklavik',
#  'zhuhai',
#  'reading',
#  'asau',
#  'padang',
#  'am timan',
#  'dubai',
#  'edson',
#  'laguna',
#  'hofn',
#  'berlevag',
#  'gamba',
#  'nizhneangarsk',
#  'okha',
#  'batouri',
#  'talaya',
#  'belmonte',
#  'vorotynsk',
#  'port blair',
#  'umm lajj',
#  'dali',
#  'tawang',
#  'doha',
#  'whitehorse',
#  'mangalia',
#  'miki',
#  'tabiauea',
#  'bengkulu',
#  'zykovo',
#  'mana',
#  'santarem',
#  'marystown',
#  'matay',
#  'mercedes',
#  'sivas',
#  'dingle',
#  'san jose',
#  'codajas',
#  'grand river south east',
#  'vila',
#  'ambilobe',
#  'neftegorsk',
#  'paradwip',
#  'mackay',
#  'whyalla',
#  'marcona',
#  'salalah',
#  'conde',
#  'sandwick',
#  'camacha',
#  'baoding',
#  'ojinaga',
#  'enumclaw',
#  'zigong',
#  'paciran',
#  'elko',
#  'muli',
#  'naftah',
#  'saryshagan',
#  'beroroha',
#  'derbent',
#  'kaeo',
#  'geraldton',
#  'phan rang',
#  'lashio',
#  'honningsvag',
#  'lokoja',
#  'el tarra',
#  'bubaque',
#  'naantali',
#  'nerchinsk',
#  'hovd',
#  'te anau',
#  'cabinda',
#  'indiana',
#  'samalaeulu',
#  'kawalu',
#  'hobyo',
#  'khandbari',
#  'feijo',
#  'halalo',
#  'camabatela',
#  'half moon bay',
#  'santa cruz de la palma',
#  'bekovo',
#  'golynki',
#  'piacabucu',
#  'shumskiy',
#  'kaseda',
#  'palasa',
#  'ayan',
#  'khandyga',
#  'mongoumba',
#  'faridan',
#  'qaqortoq',
#  'timra',
#  'bajil',
#  'ialibu',
#  'uyovu',
#  'baft',
#  'qujing',
#  'luanda',
#  'lasa',
#  'jinchang',
#  'satitoa',
#  'vagur',
#  'oktyabrskiy',
#  'sal rei',
#  'codrington',
#  'oleksandrivka',
#  'kamaishi',
#  'sherghati',
#  'meadow lake',
#  'linxia',
#  'madimba',
#  'talca',
#  'atambua',
#  'inhambane',
#  'tottori',
#  'kirkland lake',
#  'bengkalis',
#  'abu samrah',
#  'rock sound',
#  'hirara',
#  'san carlos',
#  'rungata',
#  'skierniewice',
#  'geilo',
#  'urengoy',
#  'jacqueville',
#  'egvekinot',
#  'yining',
#  'gueugnon',
#  'erzin',
#  'conceicao da barra',
#  'homer',
#  'kahului',
#  'havre-saint-pierre',
#  'muborak',
#  'serik',
#  'nakatsu',
#  'yerbogachen',
#  'mosquera',
#  'kirakira',
#  'otane',
#  'kiunga',
#  'batticaloa',
#  'camana',
#  'pacific grove',
#  'yulara',
#  'bonavista',
#  'bulawayo',
#  'mount pleasant',
#  'carlsbad',
#  'cranbourne',
#  'bolungarvik',
#  'iqaluit',
#  'novikovo',
#  'rio grande',
#  'honavar',
#  'dalnegorsk',
#  'dir',
#  'wulanhaote',
#  'sungaipenuh',
#  'ilhabela',
#  'karimganj',
#  'tyrma',
#  'moratuwa',
#  'cartagena',
#  'moerai',
#  'krasnoselkup',
#  'meulaboh',
#  'sinop',
#  'verkhoyansk',
#  'storforshei',
#  'talcahuano',
#  'sinnamary',
#  'pakala',
#  'khorramshahr',
#  'banda aceh',
#  'fort abbas',
#  'requena',
#  'calama',
#  'warqla',
#  'kostomuksha',
#  'russell',
#  'cape elizabeth',
#  'el granzal',
#  'paamiut',
#  'soderhamn',
#  'tahta',
#  'pano aqil',
#  'ormara',
#  'eregli',
#  'seguela',
#  'khorixas',
#  'zadar',
#  'dom pedrito',
#  'atasu',
#  'puerto palomas',
#  'torrington',
#  'nouna',
#  'marawi',
#  'mastic beach',
#  'vardo',
#  'parabel',
#  'el naranjo',
#  'liverpool',
#  'gulabpura',
#  'solhan',
#  'araouane',
#  'kholtoson',
#  'santa maria',
#  'bandundu',
#  'pierre',
#  'maghama',
#  'kavaratti',
#  'herat',
#  'fort nelson',
#  'zyryanskoye',
#  'daru',
#  'mangai',
#  'takaungu',
#  'broome',
#  'kommunisticheskiy',
#  'khabary',
#  'yuzhno-yeniseyskiy',
#  'lincoln',
#  'qostanay',
#  'punta alta',
#  'beira',
#  'konevo',
#  'bonthe']

# %%
units = 'imperial'
city = 'charlestown'
url = "http://api.openweathermap.org/data/2.5/weather?"
query_url = f"{url}appid={weather_api_key}&units={units}&q="
response = requests.get(query_url + city)
time.sleep(1.5)
res = response.json()

# %%
(res['sys']['country'])
# Out:
# 'AU'

# %%
pprint(res)
pprint(res["clouds"]["all"])
# Out:
# {'base': 'stations',
#  'clouds': {'all': 98},
#  'cod': 200,
#  'coord': {'lat': -32.95, 'lon': 151.67},
#  'dt': 1582386140,
#  'id': 2171766,
#  'main': {'feels_like': 69.39,
#           'humidity': 77,
#           'pressure': 1023,
#           'temp': 68.41,
#           'temp_max': 71.01,
#           'temp_min': 66.99},
#  'name': 'Charlestown',
#  'sys': {'country': 'AU',
#          'id': 9605,
#          'sunrise': 1582400173,
#          'sunset': 1582447067,
#          'type': 1},
#  'timezone': 39600,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 70, 'speed': 4.7}}
# 98

# %%
City_ID=[]
City= []         
Cloudiness=[]
Country=[]
Date=[]    
Humidity=[]
Lat=[]   
Lng=[]   
Temp=[]
Max_Temp=[]
Wind_Speed=[]
counter=0
units = 'imperial'
url = "http://api.openweathermap.org/data/2.5/weather?"
query_url = f"{url}appid={weather_api_key}&units={units}&q="

for city in cities:
    try:
        response = requests.get(query_url + city)
        res = response.json()
        City_ID.append(counter)
        Lat.append(res['coord']['lat'])
        Lng.append(res['coord']['lon'])
        City.append(res['name'])
        Cloudiness.append(res['clouds']['all'])
        Country.append(res['sys']['country'])
        Humidity.append(res['main']['humidity'])
        Temp.append(res['main']['temp'])
        Max_Temp.append(res['main']['temp_max'])
        Date.append(res['dt'])
        Wind_Speed.append(res['wind']['speed'])
        time.sleep(1.5)
        counter+=1
        print(counter)
        print((res['name']))
        print("Got a successful result. Appending to appropriate lists.")
    except KeyError:
        print("Skipped city. It doesn't exist")
# Out:
# 1
# Touros
# Got a successful result. Appending to appropriate lists.
# 2
# East London
# Got a successful result. Appending to appropriate lists.
# 3
# Bethel
# Got a successful result. Appending to appropriate lists.
# 4
# Port Elizabeth
# Got a successful result. Appending to appropriate lists.
# 5
# Alugan
# Got a successful result. Appending to appropriate lists.
# 6
# Puerto Ayora
# Got a successful result. Appending to appropriate lists.
# 7
# Punta Arenas
# Got a successful result. Appending to appropriate lists.
# 8
# Nikolskoye
# Got a successful result. Appending to appropriate lists.
# 9
# Tuktoyaktuk
# Got a successful result. Appending to appropriate lists.
# 10
# Santa Quiteria
# Got a successful result. Appending to appropriate lists.
# 11
# Butaritari
# Got a successful result. Appending to appropriate lists.
# 12
# Wamba
# Got a successful result. Appending to appropriate lists.
# 13
# Hilo
# Got a successful result. Appending to appropriate lists.
# 14
# Camacupa
# Got a successful result. Appending to appropriate lists.
# 15
# Norman Wells
# Got a successful result. Appending to appropriate lists.
# 16
# Port Lincoln
# Got a successful result. Appending to appropriate lists.
# 17
# Mataura
# Got a successful result. Appending to appropriate lists.
# 18
# Bandarbeyla
# Got a successful result. Appending to appropriate lists.
# 19
# Cape Town
# Got a successful result. Appending to appropriate lists.
# 20
# Njombe
# Got a successful result. Appending to appropriate lists.
# 21
# Ushuaia
# Got a successful result. Appending to appropriate lists.
# 22
# Serenje
# Got a successful result. Appending to appropriate lists.
# 23
# Trapani
# Got a successful result. Appending to appropriate lists.
# 24
# Nouadhibou
# Got a successful result. Appending to appropriate lists.
# 25
# Katsuura
# Got a successful result. Appending to appropriate lists.
# 26
# Xining
# Got a successful result. Appending to appropriate lists.
# 27
# Hasaki
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 28
# Kapaa
# Got a successful result. Appending to appropriate lists.
# 29
# Shimoda
# Got a successful result. Appending to appropriate lists.
# 30
# Nioro
# Got a successful result. Appending to appropriate lists.
# 31
# Gachsaran
# Got a successful result. Appending to appropriate lists.
# 32
# Saint-Philippe
# Got a successful result. Appending to appropriate lists.
# 33
# Rikitea
# Got a successful result. Appending to appropriate lists.
# 34
# Ponta do Sol
# Got a successful result. Appending to appropriate lists.
# 35
# Provideniya
# Got a successful result. Appending to appropriate lists.
# 36
# Hun
# Got a successful result. Appending to appropriate lists.
# 37
# Kaura Namoda
# Got a successful result. Appending to appropriate lists.
# 38
# San Ramon
# Got a successful result. Appending to appropriate lists.
# 39
# Torbay
# Got a successful result. Appending to appropriate lists.
# 40
# Hermanus
# Got a successful result. Appending to appropriate lists.
# 41
# Road Town
# Got a successful result. Appending to appropriate lists.
# 42
# Mount Isa
# Got a successful result. Appending to appropriate lists.
# 43
# Bluff
# Got a successful result. Appending to appropriate lists.
# 44
# Mariental
# Got a successful result. Appending to appropriate lists.
# 45
# Portree
# Got a successful result. Appending to appropriate lists.
# 46
# Sao Filipe
# Got a successful result. Appending to appropriate lists.
# 47
# Sitka
# Got a successful result. Appending to appropriate lists.
# 48
# Kutum
# Got a successful result. Appending to appropriate lists.
# 49
# Castro
# Got a successful result. Appending to appropriate lists.
# 50
# Vaini
# Got a successful result. Appending to appropriate lists.
# 51
# Albany
# Got a successful result. Appending to appropriate lists.
# 52
# Arraial do Cabo
# Got a successful result. Appending to appropriate lists.
# 53
# Lompoc
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 54
# Ternate
# Got a successful result. Appending to appropriate lists.
# 55
# Laurel
# Got a successful result. Appending to appropriate lists.
# 56
# Caravelas
# Got a successful result. Appending to appropriate lists.
# 57
# Yaounde
# Got a successful result. Appending to appropriate lists.
# 58
# Pailon
# Got a successful result. Appending to appropriate lists.
# 59
# Chara
# Got a successful result. Appending to appropriate lists.
# 60
# Nhulunbuy
# Got a successful result. Appending to appropriate lists.
# 61
# Fort Saint James
# Got a successful result. Appending to appropriate lists.
# 62
# Luderitz
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 63
# Sao Joao da Barra
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 64
# Hambantota
# Got a successful result. Appending to appropriate lists.
# 65
# Vostok
# Got a successful result. Appending to appropriate lists.
# 66
# Saskylakh
# Got a successful result. Appending to appropriate lists.
# 67
# Kattivakkam
# Got a successful result. Appending to appropriate lists.
# 68
# AEaenekoski
# Got a successful result. Appending to appropriate lists.
# 69
# Superior
# Got a successful result. Appending to appropriate lists.
# 70
# Sembakung
# Got a successful result. Appending to appropriate lists.
# 71
# Pevek
# Got a successful result. Appending to appropriate lists.
# 72
# Acapulco de Juarez
# Got a successful result. Appending to appropriate lists.
# 73
# Narang
# Got a successful result. Appending to appropriate lists.
# 74
# Yellowknife
# Got a successful result. Appending to appropriate lists.
# 75
# Atuona
# Got a successful result. Appending to appropriate lists.
# 76
# Hamilton
# Got a successful result. Appending to appropriate lists.
# 77
# Dikson
# Got a successful result. Appending to appropriate lists.
# 78
# Adrar
# Got a successful result. Appending to appropriate lists.
# 79
# Khipro
# Got a successful result. Appending to appropriate lists.
# 80
# George Town
# Got a successful result. Appending to appropriate lists.
# 81
# Busselton
# Got a successful result. Appending to appropriate lists.
# 82
# Tigil
# Got a successful result. Appending to appropriate lists.
# 83
# Jamestown
# Got a successful result. Appending to appropriate lists.
# 84
# High Rock
# Got a successful result. Appending to appropriate lists.
# 85
# Walvis Bay
# Got a successful result. Appending to appropriate lists.
# 86
# Cidreira
# Got a successful result. Appending to appropriate lists.
# 87
# Vallenar
# Got a successful result. Appending to appropriate lists.
# 88
# Flin Flon
# Got a successful result. Appending to appropriate lists.
# 89
# Hithadhoo
# Got a successful result. Appending to appropriate lists.
# 90
# Chokurdakh
# Got a successful result. Appending to appropriate lists.
# 91
# Puerto Ayacucho
# Got a successful result. Appending to appropriate lists.
# 92
# Esim
# Got a successful result. Appending to appropriate lists.
# 93
# Ilulissat
# Got a successful result. Appending to appropriate lists.
# 94
# Thompson
# Got a successful result. Appending to appropriate lists.
# 95
# Faanui
# Got a successful result. Appending to appropriate lists.
# 96
# Cabo San Lucas
# Got a successful result. Appending to appropriate lists.
# 97
# Aswan
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 98
# Nome
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 99
# Ancud
# Got a successful result. Appending to appropriate lists.
# 100
# Leningradskiy
# Got a successful result. Appending to appropriate lists.
# 101
# Chui
# Got a successful result. Appending to appropriate lists.
# 102
# Klaksvik
# Got a successful result. Appending to appropriate lists.
# 103
# Pangnirtung
# Got a successful result. Appending to appropriate lists.
# 104
# Awjilah
# Got a successful result. Appending to appropriate lists.
# 105
# Bredasdorp
# Got a successful result. Appending to appropriate lists.
# 106
# Tuatapere
# Got a successful result. Appending to appropriate lists.
# 107
# Necochea
# Got a successful result. Appending to appropriate lists.
# 108
# Barrow
# Got a successful result. Appending to appropriate lists.
# 109
# Husavik
# Got a successful result. Appending to appropriate lists.
# 110
# San Isidro
# Got a successful result. Appending to appropriate lists.
# 111
# Pandan
# Got a successful result. Appending to appropriate lists.
# 112
# Soyo
# Got a successful result. Appending to appropriate lists.
# 113
# Bucerias
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# Skipped city. It doesn't exist
# 114
# Fare
# Got a successful result. Appending to appropriate lists.
# 115
# Kodiak
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 116
# Saint George
# Got a successful result. Appending to appropriate lists.
# 117
# Petropavlovsk-Kamchatsky
# Got a successful result. Appending to appropriate lists.
# 118
# Qaanaaq
# Got a successful result. Appending to appropriate lists.
# 119
# Emilio Carranza
# Got a successful result. Appending to appropriate lists.
# 120
# Kavieng
# Got a successful result. Appending to appropriate lists.
# 121
# Ruteng
# Got a successful result. Appending to appropriate lists.
# 122
# Boende
# Got a successful result. Appending to appropriate lists.
# 123
# Douglas
# Got a successful result. Appending to appropriate lists.
# 124
# Khatanga
# Got a successful result. Appending to appropriate lists.
# 125
# Cayenne
# Got a successful result. Appending to appropriate lists.
# 126
# Vila Velha
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 127
# Maceio
# Got a successful result. Appending to appropriate lists.
# 128
# Tasiilaq
# Got a successful result. Appending to appropriate lists.
# 129
# Tsagan Aman
# Got a successful result. Appending to appropriate lists.
# 130
# Roald
# Got a successful result. Appending to appropriate lists.
# 131
# Nuuk
# Got a successful result. Appending to appropriate lists.
# 132
# Coquimbo
# Got a successful result. Appending to appropriate lists.
# 133
# Pacifica
# Got a successful result. Appending to appropriate lists.
# 134
# Iberia
# Got a successful result. Appending to appropriate lists.
# 135
# Komsomolskoye
# Got a successful result. Appending to appropriate lists.
# 136
# Karratha
# Got a successful result. Appending to appropriate lists.
# 137
# Keffi
# Got a successful result. Appending to appropriate lists.
# 138
# Tautira
# Got a successful result. Appending to appropriate lists.
# 139
# Airai
# Got a successful result. Appending to appropriate lists.
# 140
# Longyearbyen
# Got a successful result. Appending to appropriate lists.
# 141
# Winslow
# Got a successful result. Appending to appropriate lists.
# 142
# Nabire
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 143
# Korhogo
# Got a successful result. Appending to appropriate lists.
# 144
# Rundu
# Got a successful result. Appending to appropriate lists.
# 145
# Ribeira Grande
# Got a successful result. Appending to appropriate lists.
# 146
# Tula
# Got a successful result. Appending to appropriate lists.
# 147
# Henties Bay
# Got a successful result. Appending to appropriate lists.
# 148
# Veraval
# Got a successful result. Appending to appropriate lists.
# 149
# Hobart
# Got a successful result. Appending to appropriate lists.
# 150
# Marsabit
# Got a successful result. Appending to appropriate lists.
# 151
# Shurugwi
# Got a successful result. Appending to appropriate lists.
# 152
# Shelburne
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 153
# Chapais
# Got a successful result. Appending to appropriate lists.
# 154
# Beloha
# Got a successful result. Appending to appropriate lists.
# 155
# Ningbo
# Got a successful result. Appending to appropriate lists.
# 156
# Bambous Virieux
# Got a successful result. Appending to appropriate lists.
# 157
# Havelock
# Got a successful result. Appending to appropriate lists.
# 158
# Avanuorri
# Got a successful result. Appending to appropriate lists.
# 159
# Haimen
# Got a successful result. Appending to appropriate lists.
# 160
# Olinda
# Got a successful result. Appending to appropriate lists.
# 161
# Santo Domingo
# Got a successful result. Appending to appropriate lists.
# 162
# Shiyan
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 163
# Mount Gambier
# Got a successful result. Appending to appropriate lists.
# 164
# Noumea
# Got a successful result. Appending to appropriate lists.
# 165
# Moose Factory
# Got a successful result. Appending to appropriate lists.
# 166
# Palmer
# Got a successful result. Appending to appropriate lists.
# 167
# Clyde River
# Got a successful result. Appending to appropriate lists.
# 168
# Murdochville
# Got a successful result. Appending to appropriate lists.
# 169
# Shingu
# Got a successful result. Appending to appropriate lists.
# 170
# Ponta Delgada
# Got a successful result. Appending to appropriate lists.
# 171
# Lavrentiya
# Got a successful result. Appending to appropriate lists.
# 172
# Manakara
# Got a successful result. Appending to appropriate lists.
# 173
# Severo-Kuril'sk
# Got a successful result. Appending to appropriate lists.
# 174
# Okhotsk
# Got a successful result. Appending to appropriate lists.
# 175
# Vaitape
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 176
# New Norfolk
# Got a successful result. Appending to appropriate lists.
# 177
# Hailey
# Got a successful result. Appending to appropriate lists.
# 178
# Campbell River
# Got a successful result. Appending to appropriate lists.
# 179
# Mahebourg
# Got a successful result. Appending to appropriate lists.
# 180
# San Antero
# Got a successful result. Appending to appropriate lists.
# 181
# Maxixe
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 182
# Nakuru
# Got a successful result. Appending to appropriate lists.
# 183
# Wanaka
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 184
# Sorland
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 185
# Uyuni
# Got a successful result. Appending to appropriate lists.
# 186
# Bayan
# Got a successful result. Appending to appropriate lists.
# 187
# Bilopillya
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 188
# Iquique
# Got a successful result. Appending to appropriate lists.
# 189
# Tripoli
# Got a successful result. Appending to appropriate lists.
# 190
# Haines Junction
# Got a successful result. Appending to appropriate lists.
# 191
# Gorontalo
# Got a successful result. Appending to appropriate lists.
# 192
# Naze
# Got a successful result. Appending to appropriate lists.
# 193
# Kapoeta
# Got a successful result. Appending to appropriate lists.
# 194
# San Juan
# Got a successful result. Appending to appropriate lists.
# 195
# Vryburg
# Got a successful result. Appending to appropriate lists.
# 196
# Port Moresby
# Got a successful result. Appending to appropriate lists.
# 197
# Taltal
# Got a successful result. Appending to appropriate lists.
# 198
# Carnarvon
# Got a successful result. Appending to appropriate lists.
# 199
# Lagoa
# Got a successful result. Appending to appropriate lists.
# 200
# Rio Gallegos
# Got a successful result. Appending to appropriate lists.
# 201
# Mossamedes
# Got a successful result. Appending to appropriate lists.
# 202
# Lebu
# Got a successful result. Appending to appropriate lists.
# 203
# Avram Iancu
# Got a successful result. Appending to appropriate lists.
# 204
# Muzhi
# Got a successful result. Appending to appropriate lists.
# 205
# Chabahar
# Got a successful result. Appending to appropriate lists.
# 206
# Mecca
# Got a successful result. Appending to appropriate lists.
# 207
# Port Alfred
# Got a successful result. Appending to appropriate lists.
# 208
# Juneau
# Got a successful result. Appending to appropriate lists.
# 209
# Jiuquan
# Got a successful result. Appending to appropriate lists.
# 210
# Saldanha
# Got a successful result. Appending to appropriate lists.
# 211
# Oksfjord
# Got a successful result. Appending to appropriate lists.
# 212
# Najran
# Got a successful result. Appending to appropriate lists.
# 213
# La Ronge
# Got a successful result. Appending to appropriate lists.
# 214
# Terrace Bay
# Got a successful result. Appending to appropriate lists.
# 215
# Upernavik
# Got a successful result. Appending to appropriate lists.
# 216
# Cherskiy
# Got a successful result. Appending to appropriate lists.
# 217
# Jizan
# Got a successful result. Appending to appropriate lists.
# 218
# Jos
# Got a successful result. Appending to appropriate lists.
# 219
# Vestmannaeyjar
# Got a successful result. Appending to appropriate lists.
# 220
# Burnie
# Got a successful result. Appending to appropriate lists.
# 221
# Talnakh
# Got a successful result. Appending to appropriate lists.
# 222
# Mbala
# Got a successful result. Appending to appropriate lists.
# 223
# Kumul
# Got a successful result. Appending to appropriate lists.
# 224
# Apodi
# Got a successful result. Appending to appropriate lists.
# 225
# Fortuna
# Got a successful result. Appending to appropriate lists.
# 226
# Portland
# Got a successful result. Appending to appropriate lists.
# 227
# Ostrovnoy
# Got a successful result. Appending to appropriate lists.
# 228
# Saucillo
# Got a successful result. Appending to appropriate lists.
# 229
# Langham
# Got a successful result. Appending to appropriate lists.
# 230
# Karpathos
# Got a successful result. Appending to appropriate lists.
# 231
# Baykit
# Got a successful result. Appending to appropriate lists.
# 232
# Fuyang
# Got a successful result. Appending to appropriate lists.
# 233
# Yangi Marg`ilon
# Got a successful result. Appending to appropriate lists.
# 234
# Chester
# Got a successful result. Appending to appropriate lists.
# 235
# Levice
# Got a successful result. Appending to appropriate lists.
# 236
# Pangai
# Got a successful result. Appending to appropriate lists.
# 237
# Lorengau
# Got a successful result. Appending to appropriate lists.
# 238
# Vila Franca do Campo
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 239
# Las Juntas
# Got a successful result. Appending to appropriate lists.
# 240
# Polson
# Got a successful result. Appending to appropriate lists.
# 241
# Cairns
# Got a successful result. Appending to appropriate lists.
# 242
# Roros
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 243
# Qasigiannguit
# Got a successful result. Appending to appropriate lists.
# 244
# Aksha
# Got a successful result. Appending to appropriate lists.
# 245
# Port Hardy
# Got a successful result. Appending to appropriate lists.
# 246
# Brae
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 247
# Mar del Plata
# Got a successful result. Appending to appropriate lists.
# 248
# Vanimo
# Got a successful result. Appending to appropriate lists.
# 249
# Botwood
# Got a successful result. Appending to appropriate lists.
# 250
# Broken Hill
# Got a successful result. Appending to appropriate lists.
# 251
# Sergeevka
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 252
# San Cristobal
# Got a successful result. Appending to appropriate lists.
# 253
# Kedougou
# Got a successful result. Appending to appropriate lists.
# 254
# Richards Bay
# Got a successful result. Appending to appropriate lists.
# 255
# Ust'-Ilimsk
# Got a successful result. Appending to appropriate lists.
# 256
# Clarence Town
# Got a successful result. Appending to appropriate lists.
# 257
# Baneh
# Got a successful result. Appending to appropriate lists.
# 258
# Buin
# Got a successful result. Appending to appropriate lists.
# 259
# Constitucion
# Got a successful result. Appending to appropriate lists.
# 260
# Anloga
# Got a successful result. Appending to appropriate lists.
# 261
# Kuusamo
# Got a successful result. Appending to appropriate lists.
# 262
# Lengshuitan
# Got a successful result. Appending to appropriate lists.
# 263
# Lagos
# Got a successful result. Appending to appropriate lists.
# 264
# Tessalit
# Got a successful result. Appending to appropriate lists.
# 265
# Uige
# Got a successful result. Appending to appropriate lists.
# 266
# Lakhnadon
# Got a successful result. Appending to appropriate lists.
# 267
# Yumen
# Got a successful result. Appending to appropriate lists.
# 268
# Coyhaique
# Got a successful result. Appending to appropriate lists.
# 269
# Chumikan
# Got a successful result. Appending to appropriate lists.
# 270
# Honiara
# Got a successful result. Appending to appropriate lists.
# 271
# Muhos
# Got a successful result. Appending to appropriate lists.
# 272
# Waipawa
# Got a successful result. Appending to appropriate lists.
# 273
# Shizunai
# Got a successful result. Appending to appropriate lists.
# 274
# Guerrero Negro
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 275
# San Patricio
# Got a successful result. Appending to appropriate lists.
# 276
# Kandrian
# Got a successful result. Appending to appropriate lists.
# 277
# Tura
# Got a successful result. Appending to appropriate lists.
# 278
# Kaitangata
# Got a successful result. Appending to appropriate lists.
# 279
# Lampa
# Got a successful result. Appending to appropriate lists.
# 280
# Leh
# Got a successful result. Appending to appropriate lists.
# 281
# Jackson
# Got a successful result. Appending to appropriate lists.
# 282
# Tiksi
# Got a successful result. Appending to appropriate lists.
# 283
# Ardakan
# Got a successful result. Appending to appropriate lists.
# 284
# Matara
# Got a successful result. Appending to appropriate lists.
# 285
# Jiexiu
# Got a successful result. Appending to appropriate lists.
# 286
# Diu
# Got a successful result. Appending to appropriate lists.
# 287
# Ginda
# Got a successful result. Appending to appropriate lists.
# 288
# Avarua
# Got a successful result. Appending to appropriate lists.
# 289
# Hailar
# Got a successful result. Appending to appropriate lists.
# 290
# Puerto El Triunfo
# Got a successful result. Appending to appropriate lists.
# 291
# Isangel
# Got a successful result. Appending to appropriate lists.
# 292
# Ilanskiy
# Got a successful result. Appending to appropriate lists.
# 293
# Ust'-Ishim
# Got a successful result. Appending to appropriate lists.
# 294
# Hong Kong
# Got a successful result. Appending to appropriate lists.
# 295
# Alghero
# Got a successful result. Appending to appropriate lists.
# 296
# Panguna
# Got a successful result. Appending to appropriate lists.
# 297
# Souillac
# Got a successful result. Appending to appropriate lists.
# 298
# Rapid Valley
# Got a successful result. Appending to appropriate lists.
# 299
# Mayo
# Got a successful result. Appending to appropriate lists.
# 300
# Suntar
# Got a successful result. Appending to appropriate lists.
# 301
# Ust'-Kut
# Got a successful result. Appending to appropriate lists.
# 302
# Winnemucca
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 303
# Kruisfontein
# Got a successful result. Appending to appropriate lists.
# 304
# Praia
# Got a successful result. Appending to appropriate lists.
# 305
# Pitimbu
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 306
# Aykhal
# Got a successful result. Appending to appropriate lists.
# 307
# Narsaq
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 308
# Sikonge
# Got a successful result. Appending to appropriate lists.
# 309
# Verkhnyaya Toyma
# Got a successful result. Appending to appropriate lists.
# 310
# Bam
# Got a successful result. Appending to appropriate lists.
# 311
# Pemberton
# Got a successful result. Appending to appropriate lists.
# 312
# Esperance
# Got a successful result. Appending to appropriate lists.
# 313
# Lethem
# Got a successful result. Appending to appropriate lists.
# 314
# Olafsvik
# Got a successful result. Appending to appropriate lists.
# 315
# Townsville
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 316
# Praxedis Guerrero
# Got a successful result. Appending to appropriate lists.
# 317
# Fukuecho
# Got a successful result. Appending to appropriate lists.
# 318
# Sao Gabriel da Cachoeira
# Got a successful result. Appending to appropriate lists.
# 319
# Bahia Blanca
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 320
# Wattegama
# Got a successful result. Appending to appropriate lists.
# 321
# Viedma
# Got a successful result. Appending to appropriate lists.
# 322
# Raja
# Got a successful result. Appending to appropriate lists.
# 323
# Bathsheba
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 324
# Antalaha
# Got a successful result. Appending to appropriate lists.
# 325
# Leeuwarden
# Got a successful result. Appending to appropriate lists.
# 326
# Lata
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 327
# Whitefish
# Got a successful result. Appending to appropriate lists.
# 328
# Kyren
# Got a successful result. Appending to appropriate lists.
# 329
# Rocha
# Got a successful result. Appending to appropriate lists.
# 330
# Lucea
# Got a successful result. Appending to appropriate lists.
# 331
# Muisne
# Got a successful result. Appending to appropriate lists.
# 332
# San Diego de la Union
# Got a successful result. Appending to appropriate lists.
# 333
# Kholodnyy
# Got a successful result. Appending to appropriate lists.
# 334
# Littlehampton
# Got a successful result. Appending to appropriate lists.
# 335
# Pemba
# Got a successful result. Appending to appropriate lists.
# 336
# Baruun-Urt
# Got a successful result. Appending to appropriate lists.
# 337
# Erdaojiang
# Got a successful result. Appending to appropriate lists.
# 338
# Santa Cruz de la Sierra
# Got a successful result. Appending to appropriate lists.
# 339
# Lubao
# Got a successful result. Appending to appropriate lists.
# 340
# Salinopolis
# Got a successful result. Appending to appropriate lists.
# 341
# Arlit
# Got a successful result. Appending to appropriate lists.
# 342
# Nanortalik
# Got a successful result. Appending to appropriate lists.
# 343
# Ulladulla
# Got a successful result. Appending to appropriate lists.
# 344
# Gravdal
# Got a successful result. Appending to appropriate lists.
# 345
# Aklavik
# Got a successful result. Appending to appropriate lists.
# 346
# Zhuhai
# Got a successful result. Appending to appropriate lists.
# 347
# Reading
# Got a successful result. Appending to appropriate lists.
# 348
# Asau
# Got a successful result. Appending to appropriate lists.
# 349
# Padang
# Got a successful result. Appending to appropriate lists.
# 350
# Am Timan
# Got a successful result. Appending to appropriate lists.
# 351
# Dubai
# Got a successful result. Appending to appropriate lists.
# 352
# Edson
# Got a successful result. Appending to appropriate lists.
# 353
# Laguna
# Got a successful result. Appending to appropriate lists.
# 354
# Hofn
# Got a successful result. Appending to appropriate lists.
# 355
# Berlevag
# Got a successful result. Appending to appropriate lists.
# 356
# Gamba
# Got a successful result. Appending to appropriate lists.
# 357
# Nizhneangarsk
# Got a successful result. Appending to appropriate lists.
# 358
# Okha
# Got a successful result. Appending to appropriate lists.
# 359
# Batouri
# Got a successful result. Appending to appropriate lists.
# 360
# Talaya
# Got a successful result. Appending to appropriate lists.
# 361
# Belmonte
# Got a successful result. Appending to appropriate lists.
# 362
# Vorotynsk
# Got a successful result. Appending to appropriate lists.
# 363
# Port Blair
# Got a successful result. Appending to appropriate lists.
# 364
# Umm Lajj
# Got a successful result. Appending to appropriate lists.
# 365
# Dali
# Got a successful result. Appending to appropriate lists.
# 366
# Tawang
# Got a successful result. Appending to appropriate lists.
# 367
# Doha
# Got a successful result. Appending to appropriate lists.
# 368
# Whitehorse
# Got a successful result. Appending to appropriate lists.
# 369
# Mangalia
# Got a successful result. Appending to appropriate lists.
# 370
# Miki
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 371
# Bengkulu
# Got a successful result. Appending to appropriate lists.
# 372
# Zykovo
# Got a successful result. Appending to appropriate lists.
# 373
# Mana
# Got a successful result. Appending to appropriate lists.
# 374
# Santarem
# Got a successful result. Appending to appropriate lists.
# 375
# Marystown
# Got a successful result. Appending to appropriate lists.
# 376
# Matay
# Got a successful result. Appending to appropriate lists.
# 377
# Mercedes
# Got a successful result. Appending to appropriate lists.
# 378
# Sivas
# Got a successful result. Appending to appropriate lists.
# 379
# Dingle
# Got a successful result. Appending to appropriate lists.
# 380
# San Jose
# Got a successful result. Appending to appropriate lists.
# 381
# Codajas
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 382
# Vila
# Got a successful result. Appending to appropriate lists.
# 383
# Ambilobe
# Got a successful result. Appending to appropriate lists.
# 384
# Neftegorsk
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 385
# Mackay
# Got a successful result. Appending to appropriate lists.
# 386
# Whyalla
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 387
# Salalah
# Got a successful result. Appending to appropriate lists.
# 388
# Conde
# Got a successful result. Appending to appropriate lists.
# 389
# Sandwick
# Got a successful result. Appending to appropriate lists.
# 390
# Camacha
# Got a successful result. Appending to appropriate lists.
# 391
# Baoding
# Got a successful result. Appending to appropriate lists.
# 392
# Ojinaga
# Got a successful result. Appending to appropriate lists.
# 393
# Enumclaw
# Got a successful result. Appending to appropriate lists.
# 394
# Zigong
# Got a successful result. Appending to appropriate lists.
# 395
# Paciran
# Got a successful result. Appending to appropriate lists.
# 396
# Elko
# Got a successful result. Appending to appropriate lists.
# 397
# Muli
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# Skipped city. It doesn't exist
# 398
# Beroroha
# Got a successful result. Appending to appropriate lists.
# 399
# Derbent
# Got a successful result. Appending to appropriate lists.
# 400
# Kaeo
# Got a successful result. Appending to appropriate lists.
# 401
# Geraldton
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 402
# Lashio
# Got a successful result. Appending to appropriate lists.
# 403
# Honningsvag
# Got a successful result. Appending to appropriate lists.
# 404
# Lokoja
# Got a successful result. Appending to appropriate lists.
# 405
# El Tarra
# Got a successful result. Appending to appropriate lists.
# 406
# Bubaque
# Got a successful result. Appending to appropriate lists.
# 407
# Naantali
# Got a successful result. Appending to appropriate lists.
# 408
# Nerchinsk
# Got a successful result. Appending to appropriate lists.
# 409
# Khovd
# Got a successful result. Appending to appropriate lists.
# 410
# Te Anau
# Got a successful result. Appending to appropriate lists.
# 411
# Cabinda
# Got a successful result. Appending to appropriate lists.
# 412
# Indiana
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 413
# Kawalu
# Got a successful result. Appending to appropriate lists.
# 414
# Hobyo
# Got a successful result. Appending to appropriate lists.
# 415
# Khanbari
# Got a successful result. Appending to appropriate lists.
# 416
# Feijo
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 417
# Camabatela
# Got a successful result. Appending to appropriate lists.
# 418
# Half Moon Bay
# Got a successful result. Appending to appropriate lists.
# 419
# Santa Cruz de la Palma
# Got a successful result. Appending to appropriate lists.
# 420
# Bekovo
# Got a successful result. Appending to appropriate lists.
# 421
# Golynki
# Got a successful result. Appending to appropriate lists.
# 422
# Piacabucu
# Got a successful result. Appending to appropriate lists.
# 423
# Shumskiy
# Got a successful result. Appending to appropriate lists.
# 424
# Kaseda
# Got a successful result. Appending to appropriate lists.
# 425
# Palasa
# Got a successful result. Appending to appropriate lists.
# 426
# Ayan
# Got a successful result. Appending to appropriate lists.
# 427
# Khandyga
# Got a successful result. Appending to appropriate lists.
# 428
# Mongoumba
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 429
# Qaqortoq
# Got a successful result. Appending to appropriate lists.
# 430
# Timra
# Got a successful result. Appending to appropriate lists.
# 431
# Bajil
# Got a successful result. Appending to appropriate lists.
# 432
# Ialibu
# Got a successful result. Appending to appropriate lists.
# 433
# Uyovu
# Got a successful result. Appending to appropriate lists.
# 434
# Baft
# Got a successful result. Appending to appropriate lists.
# 435
# Qujing
# Got a successful result. Appending to appropriate lists.
# 436
# Luanda
# Got a successful result. Appending to appropriate lists.
# 437
# Laas
# Got a successful result. Appending to appropriate lists.
# 438
# Jinchang
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 439
# Vagur
# Got a successful result. Appending to appropriate lists.
# 440
# Oktyabrskiy
# Got a successful result. Appending to appropriate lists.
# 441
# Sal Rei
# Got a successful result. Appending to appropriate lists.
# 442
# Codrington
# Got a successful result. Appending to appropriate lists.
# 443
# Oleksandrivka
# Got a successful result. Appending to appropriate lists.
# 444
# Kamaishi
# Got a successful result. Appending to appropriate lists.
# 445
# Sherghati
# Got a successful result. Appending to appropriate lists.
# 446
# Meadow Lake
# Got a successful result. Appending to appropriate lists.
# 447
# Linxia
# Got a successful result. Appending to appropriate lists.
# 448
# Madimba
# Got a successful result. Appending to appropriate lists.
# 449
# Talca
# Got a successful result. Appending to appropriate lists.
# 450
# Atambua
# Got a successful result. Appending to appropriate lists.
# 451
# Inhambane
# Got a successful result. Appending to appropriate lists.
# 452
# Tottori
# Got a successful result. Appending to appropriate lists.
# 453
# Kirkland Lake
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 454
# Abu Samrah
# Got a successful result. Appending to appropriate lists.
# 455
# Rock Sound
# Got a successful result. Appending to appropriate lists.
# 456
# Hirara
# Got a successful result. Appending to appropriate lists.
# 457
# San Carlos
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 458
# Skierniewice
# Got a successful result. Appending to appropriate lists.
# 459
# Geilo
# Got a successful result. Appending to appropriate lists.
# 460
# Urengoy
# Got a successful result. Appending to appropriate lists.
# 461
# Jacqueville
# Got a successful result. Appending to appropriate lists.
# 462
# Egvekinot
# Got a successful result. Appending to appropriate lists.
# 463
# Yining
# Got a successful result. Appending to appropriate lists.
# 464
# Gueugnon
# Got a successful result. Appending to appropriate lists.
# 465
# Erzin
# Got a successful result. Appending to appropriate lists.
# 466
# Conceicao da Barra
# Got a successful result. Appending to appropriate lists.
# 467
# Homer
# Got a successful result. Appending to appropriate lists.
# 468
# Kahului
# Got a successful result. Appending to appropriate lists.
# 469
# Havre-Saint-Pierre
# Got a successful result. Appending to appropriate lists.
# 470
# Muborak
# Got a successful result. Appending to appropriate lists.
# 471
# Serik
# Got a successful result. Appending to appropriate lists.
# 472
# Nakatsu
# Got a successful result. Appending to appropriate lists.
# 473
# Yerbogachen
# Got a successful result. Appending to appropriate lists.
# 474
# Mosquera
# Got a successful result. Appending to appropriate lists.
# 475
# Kirakira
# Got a successful result. Appending to appropriate lists.
# 476
# Otane
# Got a successful result. Appending to appropriate lists.
# 477
# Kiunga
# Got a successful result. Appending to appropriate lists.
# 478
# Batticaloa
# Got a successful result. Appending to appropriate lists.
# 479
# Camana
# Got a successful result. Appending to appropriate lists.
# 480
# Pacific Grove
# Got a successful result. Appending to appropriate lists.
# 481
# Yulara
# Got a successful result. Appending to appropriate lists.
# 482
# Bonavista
# Got a successful result. Appending to appropriate lists.
# 483
# Bulawayo
# Got a successful result. Appending to appropriate lists.
# 484
# Mount Pleasant
# Got a successful result. Appending to appropriate lists.
# 485
# Carlsbad
# Got a successful result. Appending to appropriate lists.
# 486
# Cranbourne
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 487
# Iqaluit
# Got a successful result. Appending to appropriate lists.
# 488
# Novikovo
# Got a successful result. Appending to appropriate lists.
# 489
# Rio Grande
# Got a successful result. Appending to appropriate lists.
# 490
# Honavar
# Got a successful result. Appending to appropriate lists.
# 491
# Dalnegorsk
# Got a successful result. Appending to appropriate lists.
# 492
# Dir
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 493
# Sungaipenuh
# Got a successful result. Appending to appropriate lists.
# 494
# Ilhabela
# Got a successful result. Appending to appropriate lists.
# 495
# Karimganj
# Got a successful result. Appending to appropriate lists.
# 496
# Tyrma
# Got a successful result. Appending to appropriate lists.
# 497
# Moratuwa
# Got a successful result. Appending to appropriate lists.
# 498
# Cartagena
# Got a successful result. Appending to appropriate lists.
# 499
# Moerai
# Got a successful result. Appending to appropriate lists.
# 500
# Krasnosel'kup
# Got a successful result. Appending to appropriate lists.
# 501
# Meulaboh
# Got a successful result. Appending to appropriate lists.
# 502
# Sinop
# Got a successful result. Appending to appropriate lists.
# 503
# Verkhoyansk
# Got a successful result. Appending to appropriate lists.
# 504
# Storforshei
# Got a successful result. Appending to appropriate lists.
# 505
# Talcahuano
# Got a successful result. Appending to appropriate lists.
# 506
# Sinnamary
# Got a successful result. Appending to appropriate lists.
# 507
# Pakala
# Got a successful result. Appending to appropriate lists.
# 508
# Khorramshahr
# Got a successful result. Appending to appropriate lists.
# 509
# Banda Aceh
# Got a successful result. Appending to appropriate lists.
# 510
# Fort Abbas
# Got a successful result. Appending to appropriate lists.
# 511
# Requena
# Got a successful result. Appending to appropriate lists.
# 512
# Calama
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 513
# Kostomuksha
# Got a successful result. Appending to appropriate lists.
# 514
# Russell
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# Skipped city. It doesn't exist
# 515
# Paamiut
# Got a successful result. Appending to appropriate lists.
# 516
# Soederhamn
# Got a successful result. Appending to appropriate lists.
# 517
# Tahta
# Got a successful result. Appending to appropriate lists.
# 518
# Pano Aqil
# Got a successful result. Appending to appropriate lists.
# 519
# Ormara
# Got a successful result. Appending to appropriate lists.
# 520
# Heraclea
# Got a successful result. Appending to appropriate lists.
# 521
# Seguela
# Got a successful result. Appending to appropriate lists.
# 522
# Khorixas
# Got a successful result. Appending to appropriate lists.
# 523
# Zadar
# Got a successful result. Appending to appropriate lists.
# 524
# Dom Pedrito
# Got a successful result. Appending to appropriate lists.
# 525
# Atasu
# Got a successful result. Appending to appropriate lists.
# 526
# Puerto Palomas
# Got a successful result. Appending to appropriate lists.
# 527
# Torrington
# Got a successful result. Appending to appropriate lists.
# 528
# Nouna
# Got a successful result. Appending to appropriate lists.
# 529
# Marawi
# Got a successful result. Appending to appropriate lists.
# 530
# Mastic Beach
# Got a successful result. Appending to appropriate lists.
# 531
# Vardo
# Got a successful result. Appending to appropriate lists.
# 532
# Parabel
# Got a successful result. Appending to appropriate lists.
# 533
# El Rodeo (El Naranjo)
# Got a successful result. Appending to appropriate lists.
# 534
# Liverpool
# Got a successful result. Appending to appropriate lists.
# 535
# Gulabpura
# Got a successful result. Appending to appropriate lists.
# 536
# Solhan
# Got a successful result. Appending to appropriate lists.
# 537
# Araouane
# Got a successful result. Appending to appropriate lists.
# 538
# Kholtoson
# Got a successful result. Appending to appropriate lists.
# 539
# Santa Maria
# Got a successful result. Appending to appropriate lists.
# 540
# Bandundu
# Got a successful result. Appending to appropriate lists.
# 541
# Pierre
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 542
# Kavaratti
# Got a successful result. Appending to appropriate lists.
# 543
# Herat
# Got a successful result. Appending to appropriate lists.
# 544
# Fort Nelson
# Got a successful result. Appending to appropriate lists.
# 545
# Zyryanskoye
# Got a successful result. Appending to appropriate lists.
# 546
# Daru
# Got a successful result. Appending to appropriate lists.
# 547
# Mangai
# Got a successful result. Appending to appropriate lists.
# 548
# Takaungu
# Got a successful result. Appending to appropriate lists.
# 549
# Broome
# Got a successful result. Appending to appropriate lists.
# 550
# Kommunisticheskiy
# Got a successful result. Appending to appropriate lists.
# 551
# Khabary
# Got a successful result. Appending to appropriate lists.
# Skipped city. It doesn't exist
# 552
# Lincoln
# Got a successful result. Appending to appropriate lists.
# 553
# Kostanay
# Got a successful result. Appending to appropriate lists.
# 554
# Punta Alta
# Got a successful result. Appending to appropriate lists.
# 555
# Beira
# Got a successful result. Appending to appropriate lists.
# 556
# Konevo
# Got a successful result. Appending to appropriate lists.
# 557
# Bonthe
# Got a successful result. Appending to appropriate lists.

# %%
print(Humidity)
# Out:
# [70, 68, 29, 69, 80, 78, 59, 80, 84, 90, 70, 9, 77, 74, 77, 74, 77, 73, 82, 94, 63, 83, 59, 68, 66, 21, 76, 78, 49, 6, 59, 69, 71, 72, 99, 35, 8, 52, 67, 99, 65, 54, 77, 49, 60, 80, 80, 8, 89, 94, 37, 78, 81, 93, 26, 84, 36, 46, 79, 94, 86, 57, 65, 100, 96, 94, 78, 93, 79, 78, 98, 61, 77, 76, 79, 59, 91, 6, 28, 88, 58, 92, 53, 73, 53, 69, 53, 68, 85, 96, 43, 70, 59, 84, 78, 72, 20, 82, 36, 94, 59, 86, 59, 43, 82, 77, 65, 76, 76, 69, 81, 80, 88, 78, 52, 49, 65, 64, 75, 72, 98, 29, 64, 87, 74, 74, 62, 61, 64, 80, 61, 87, 81, 61, 85, 79, 21, 78, 92, 65, 87, 98, 10, 45, 72, 88, 81, 55, 76, 38, 55, 68, 73, 71, 81, 78, 51, 64, 67, 74, 70, 72, 100, 78, 58, 31, 74, 76, 57, 67, 100, 90, 90, 86, 78, 76, 72, 85, 78, 66, 70, 77, 77, 94, 67, 93, 73, 57, 69, 99, 91, 67, 27, 27, 49, 78, 66, 78, 82, 46, 85, 49, 84, 86, 75, 41, 81, 98, 25, 64, 64, 36, 63, 74, 97, 98, 74, 12, 59, 91, 91, 89, 53, 56, 93, 92, 89, 55, 85, 58, 95, 53, 81, 25, 55, 86, 72, 67, 78, 85, 94, 50, 59, 71, 100, 81, 59, 81, 57, 26, 96, 78, 17, 81, 97, 77, 84, 49, 64, 66, 100, 86, 59, 6, 69, 50, 39, 33, 85, 94, 100, 93, 89, 69, 78, 87, 45, 70, 60, 59, 92, 88, 20, 74, 34, 58, 81, 94, 92, 31, 88, 96, 96, 72, 63, 91, 78, 32, 23, 98, 96, 67, 69, 54, 100, 83, 37, 51, 83, 32, 97, 73, 38, 72, 96, 70, 61, 94, 26, 100, 20, 9, 62, 79, 81, 40, 85, 81, 61, 74, 88, 80, 93, 87, 94, 65, 87, 50, 83, 84, 6, 62, 100, 80, 83, 82, 62, 75, 85, 8, 69, 59, 65, 55, 77, 82, 96, 97, 13, 97, 84, 64, 78, 45, 63, 97, 77, 72, 70, 66, 89, 85, 80, 94, 69, 31, 22, 99, 90, 50, 95, 59, 87, 94, 83, 82, 69, 100, 86, 82, 24, 61, 93, 60, 90, 85, 72, 77, 76, 100, 78, 47, 74, 9, 55, 57, 87, 88, 58, 70, 83, 50, 95, 70, 87, 91, 81, 81, 60, 92, 76, 60, 96, 69, 70, 67, 97, 19, 37, 100, 66, 97, 85, 61, 97, 74, 36, 26, 77, 92, 60, 78, 66, 62, 82, 86, 26, 83, 72, 87, 70, 64, 68, 72, 76, 82, 35, 49, 83, 85, 88, 100, 74, 41, 82, 83, 85, 77, 85, 61, 66, 46, 96, 59, 86, 84, 98, 93, 70, 87, 14, 70, 48, 30, 87, 93, 60, 98, 49, 60, 84, 59, 98, 84, 42, 97, 70, 74, 67, 92, 69, 81, 100, 98, 86, 84, 57, 43, 90, 48, 45, 26, 97, 33, 78, 94, 32, 64, 65, 83, 19, 31, 50, 46, 92, 75, 21, 6, 85, 41, 69, 95, 65, 61, 39, 98, 6, 88, 39, 47, 74, 72, 44, 67, 97, 91, 52, 70, 46, 91, 96, 74, 100, 47, 66, 81, 65]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
data = zip(City_ID,City,Cloudiness,Country,Date,Humidity,Lat,Lng,Temp,Max_Temp,Wind_Speed)
rows = 9
labels = ['City ID','City','Cloudiness','Country','Date','Humidity','Lat','Lng','Temp','Max_Temp','Wind_Speed']
with open ("output.csv","w", newline="") as f:
    writer=csv.DictWriter(f, fieldnames = ['City ID','City','Cloudiness','Country','Date','Humidity','Lat','Lng','Max_Temp','Wind_Speed'])
    writer.writeheader()
    writer=csv.writer(f)
    writer.writerows(data)

# %%
weather = pd.read_csv("output.csv", index_col=False)
weather.count()
# Out:
# City ID       557
# City          557
# Cloudiness    557
# Country       551
# Date          557
# Humidity      557
# Lat           557
# Lng           557
# Max_Temp      557
# Wind_Speed    557
# dtype: int64

# %%
weather.head()
# Out:
#    City ID            City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0          Touros          40      BR  1582386147        70  -5.20
# 1        1     East London          51      ZA  1582386148        68 -33.02
# 2        2          Bethel           1      US  1582385872        29  41.37
# 3        3  Port Elizabeth          20      ZA  1582386003        69 -33.92
# 4        4          Alugan          32      PH  1582386153        80  12.22
#
#       Lng  Max_Temp  Wind_Speed
# 0  -35.46     86.00       86.00
# 1   27.91     71.60       71.60
# 2  -73.41     37.63       41.00
# 3   25.57     73.40       73.40
# 4  125.48     77.81       77.81

# %%
weather = weather.dropna()

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
weather=weather.rename(columns={"Max_Temp":"MaxTemp"})
plt.scatter(weather.Lat,weather.MaxTemp,marker="o", facecolors="blue", edgecolors="black",alpha=0.75)
plt.show()
plt.savefig('TempVsLat.png')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather.Lat,weather.Humidity,marker="o", facecolors="blue", edgecolors="black",alpha=0.75)
plt.show()
plt.savefig('HumidVsLat.png')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather.Lat,weather.Cloudiness,marker="o", facecolors="blue", edgecolors="black",alpha=0.75)
plt.show()
plt.savefig('CloudVsLat.png')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
weather=weather.rename(columns={"Wind_Speed":"Speed"})
plt.scatter(weather.Lat,weather.Speed,marker="o", facecolors="blue", edgecolors="black",alpha=0.75)
plt.show()
plt.savefig('WindVsLat.png')

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
weather['Hemisphere'] = np.where(weather['Lat']>=0, 'North', 'South')
weather.head()

Northdf = weather.loc[weather['Hemisphere'] != 'South']
Southdf = weather.loc[weather['Hemisphere'] != 'North']

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = Northdf['Lat']
y_values = Northdf['MaxTemp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.scatter(Northdf.Lat,Northdf.MaxTemp,marker="o", facecolors="blue", edgecolors="black",alpha=0.75)
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Lattitude')
plt.ylabel('Max Temperature')


plt.show()
print(f"The r-squared is: {rvalue}")
# Out:
# The r-squared is: -0.8749192354769394

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = Southdf['Lat']
y_values = Southdf['MaxTemp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.scatter(Southdf.Lat,Southdf.MaxTemp,marker="o", facecolors="blue", edgecolors="black",alpha=0.75)
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Lattitude')
plt.ylabel('Max Temperature')


plt.show()
print(f"The r-squared is: {rvalue}")
# Out:
# The r-squared is: 0.6668124940557357

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = Northdf['Lat']
y_values = Northdf['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.scatter(Northdf.Lat,Northdf.Humidity,marker="o", facecolors="blue", edgecolors="black",alpha=0.75)
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Lattitude')
plt.ylabel('Humidity')


plt.show()
print(f"The r-squared is: {rvalue}")
# Out:
# The r-squared is: 0.401170872837767

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = Southdf['Lat']
y_values = Southdf['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.scatter(Southdf.Lat,Southdf.Humidity,marker="o", facecolors="blue", edgecolors="black",alpha=0.75)
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Lattitude')
plt.ylabel('Humidity')


plt.show()
print(f"The r-squared is: {rvalue}")
# Out:
# The r-squared is: 0.32931800082288326

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = Northdf['Lat']
y_values = Northdf['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.scatter(Northdf.Lat,Northdf.Cloudiness,marker="o", facecolors="blue", edgecolors="black",alpha=0.75)
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Lattitude')
plt.ylabel('Cloudiness')

print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.3006274962498613

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = Southdf['Lat']
y_values = Southdf['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.scatter(Southdf.Lat,Southdf.Cloudiness,marker="o", facecolors="blue", edgecolors="black",alpha=0.75)
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Lattitude')
plt.ylabel('Cloudiness')


plt.show()
print(f"The r-squared is: {rvalue}")
# Out:
# The r-squared is: 0.35083981400869757

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = Northdf['Lat']
y_values = Northdf['Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.scatter(Northdf.Lat,Northdf.Speed,marker="o", facecolors="blue", edgecolors="black",alpha=0.75)
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Lattitude')
plt.ylabel('Wind Speed')



print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: -0.8714382146078569

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = Southdf['Lat']
y_values = Southdf['Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.scatter(Southdf.Lat,Southdf.Speed,marker="o", facecolors="blue", edgecolors="black",alpha=0.75)
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Lattitude')
plt.ylabel('Wind Speed')


plt.show()
print(f"The r-squared is: {rvalue}")
# Out:
# The r-squared is: 0.6344015584100032

# %%
weather.head()
# Out:
#    City ID            City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0          Touros          40      BR  1582386147        70  -5.20
# 1        1     East London          51      ZA  1582386148        68 -33.02
# 2        2          Bethel           1      US  1582385872        29  41.37
# 3        3  Port Elizabeth          20      ZA  1582386003        69 -33.92
# 4        4          Alugan          32      PH  1582386153        80  12.22
#
#       Lng  MaxTemp  Speed Hemisphere
# 0  -35.46    86.00  86.00      South
# 1   27.91    71.60  71.60      South
# 2  -73.41    37.63  41.00      North
# 3   25.57    73.40  73.40      South
# 4  125.48    77.81  77.81      North

# %%
## OBSERVABLE TRENDS
# 1. The farther away from 0 Lat, the higher the Wind, Cloud, and Humidity levels are, 
#   although the rate for the Southern Hemisphere is slightly larger than that of the North.

# 2. Temperature has a higher rate from 0 Lat in the Northern Hemisphere.

# 3. Highest wind speeds occur at around 50 and -50 Lats in each hemisphere respectively
